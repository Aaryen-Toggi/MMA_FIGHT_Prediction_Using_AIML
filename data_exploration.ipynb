# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)  # Show all columns in the DataFrame
pd.set_option('display.max_info_columns', 200)  # Show all columns in DataFrame info

# %%
df = pd.read_csv('ufc-master.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6541 entries, 0 to 6540
# Data columns (total 118 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    RedFighter                   6541 non-null   object
#  1    BlueFighter                  6541 non-null   object
#  2    RedOdds                      6314 non-null   float64
#  3    BlueOdds                     6315 non-null   float64
#  4    RedExpectedValue             6314 non-null   float64
#  5    BlueExpectedValue            6315 non-null   float64
#  6    Date                         6541 non-null   object
#  7    Location                     6541 non-null   object
#  8    Country                      6541 non-null   object
#  9    Winner                       6541 non-null   object
#  10   TitleBout                    6541 non-null   bool
#  11   WeightClass                  6541 non-null   object
# ...

# %%
df.select_dtypes(include='object').info()
# df.select_dtypes(include='number').info()
# print("Unique values in:")
# print("WeightClass: ", df['WeightClass'].unique().tolist())
# print("Finish: ", df['Finish'].unique().tolist())
# print("BlueStance: ", df['BlueStance'].unique().tolist())
# print("RedStance: ", df['RedStance'].unique().tolist())

# print("row where stance is 'nan': \n", df[(df['BlueStance'].isna()) | (df['RedStance'].isna())])

# Unique values in each categorical column
categorical_columns = ['WeightClass','Gender','BlueStance','RedStance','BetterRank','Finish']
# categorical_columns = df.select_dtypes(include='object').columns
for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"Unique values in {col}: {unique_values}\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6541 entries, 0 to 6540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RedFighter       6541 non-null   object
#  1   BlueFighter      6541 non-null   object
#  2   Date             6541 non-null   object
#  3   Location         6541 non-null   object
#  4   Country          6541 non-null   object
#  5   Winner           6541 non-null   object
#  6   WeightClass      6541 non-null   object
#  7   Gender           6541 non-null   object
#  8   BlueStance       6541 non-null   object
#  9   RedStance        6541 non-null   object
#  10  BetterRank       6541 non-null   object
#  11  Finish           6303 non-null   object
#  12  FinishDetails    2898 non-null   object
#  13  FinishRoundTime  5919 non-null   object
# dtypes: object(14)
# memory usage: 715.6+ KB
# ...
